# %%
import nltk

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import urllib.request
from bs4 import BeautifulSoup

response=urllib.request.urlopen('https://editorialorsai.com/category/epocas/')
html=response.read()

soup=BeautifulSoup(html,'html5lib')
text=soup.get_text(strip=True)

tokens=[t for t in text.split()]

print(html)
#print(text)
#print(tokens)
# Out:
# b'<!doctype html>\r\n\r\n<html lang="es-AR" class="is-header-fixed">\r\n\r\n<head>\r\n\t<meta charset="UTF-8">\r\n\t\r\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\r\n\t\t\t\t\r\n\t<title>\xc3\x89pocas | Editorial Orsai</title>\r\n\t\r\n\t\n\t<!-- This site is optimized with the Yoast SEO plugin v14.2 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<meta name="robots" content="index, follow" />\n\t<meta name="googlebot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n\t<meta name="bingbot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />\n\t<link rel="canonical" href="https://editorialorsai.com/category/epocas/" />\n\t<meta property="og:locale" content="es_ES" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="\xc3\x89pocas | Editorial Orsai" />\n\t<meta property="og:description" content="M\xc3\xa1s de doce a\xc3\xb1os intentando escribir dos p\xc3\xa1rrafos decentes" />\n\t<meta property="og:url" content="https://editorialorsai.com/category/epocas/" />\n\t<meta property="og:site_name" content="Editorial Orsai" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://editorialorsai.com/#website","url":"https://editorialorsai.com/","name":"Editorial Orsai","description":"BLOG, REVISTA, EDITORIAL Y PROYECTO ORSAI \\u2014 Lo que empez\\u00f3 siendo un blog puede convertirse en cualquier cosa.","potentialAction":[{"@type":"SearchAction","target":"https://editorialorsai.com/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"es-AR"},{"@type":"CollectionPage","@id":"https://editorialorsai.com/category/epocas/#webpage","url":"https://editorialorsai.com/category/epocas/","name":"\\u00c9pocas | Editorial Orsai","isPartOf":{"@id":"https://editorialorsai.com/#website"},"inLanguage":"es-AR"}]}</script>\n\t<!-- / Yoast SEO plugin. -->\n\n\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Editorial Orsai &raquo; Feed" href="https://editorialorsai.com/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Editorial Orsai &raquo; RSS de los comentarios" href="https://editorialorsai.com/comments/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Editorial Orsai &raquo; \xc3\x89pocas RSS de la categor\xc3\xada" href="https://editorialorsai.com/category/epocas/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/editorialorsai.com\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.4.1"}};\n\t\t\t/*! This file is auto-generated */\n\t\t\t!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createEle ...

# %%
from nltk.tokenize import sent_tokenize
print(sent_tokenize(text))
# Out:
# ['Épocas | Editorial Orsai{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://editorialorsai.com/#website","url":"https://editorialorsai.com/","name":"Editorial Orsai","description":"BLOG, REVISTA, EDITORIAL Y PROYECTO ORSAI \\u2014 Lo que empez\\u00f3 siendo un blog puede convertirse en cualquier cosa.', '","potentialAction":[{"@type":"SearchAction","target":"https://editorialorsai.com/?s={search_term_string}","query-input":"required name=search_term_string"}],"inLanguage":"es-AR"},{"@type":"CollectionPage","@id":"https://editorialorsai.com/category/epocas/#webpage","url":"https://editorialorsai.com/category/epocas/","name":"\\u00c9pocas | Editorial Orsai","isPartOf":{"@id":"https://editorialorsai.com/#website"},"inLanguage":"es-AR"}]}window._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/12.0.0-1\\/svg\\/","svgExt":".svg","source":{"concatemoji":"https:\\/\\/editorialorsai.com\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=5.4.1"}};\n\t\t\t/*!', 'This file is auto-generated */\n\t\t\t!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?', '(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);img.wp-smiley,\nimg.emoji {\n\tdisplay: inline !important;\n\tborder: none !important;\n\tbox-shadow: none !important;\n\theight: 1em !important;\n\twidth: 1em !important;\n\tmargin: 0 .07em !important;\n\tvertical-align: -0.1em !important;\n\tbackground: none !important;\n\tpadding: 0 !important;\n}/* <!', '[CDATA[ */\nvar misha_loadmore_params = {"ajaxurl":"https:\\/\\/editorialorsai.com\\/wp-admin\\/admin-ajax.php","posts":"{\\"category_name\\":\\"epocas\\",\\"error\\":\\"\\",\\"m\\":\\"\\",\\"p\\":0,\\"post_parent\\":\\"\\",\\"subpost\\":\\"\\",\\"subpost_id\\":\\"\\",\\"attachment\\":\\"\\",\\"attachment_id\\":0,\\"name\\":\\"\\",\\"pagename\\":\\"\\",\\"page_id\\":0,\\"second\\":\\"\\",\\"minute\\":\\"\\",\\"hour\\":\\"\\",\\"day\\":0,\\"monthnum\\":0,\\"year\\":0,\\"w\\":0,\\"tag\\":\\"\\",\\"cat\\":2617,\\"tag_id\\":\\"\\",\\"author\\":\\"\\",\\"author_name\\":\\"\\",\\"feed\\":\\"\\",\\"tb\\":\\"\\",\\"paged\\":0,\\"me ...

# %%
import bs4 
import urllib.request
from bs4 import BeautifulSoup
import re

response=urllib.request.urlopen('https://editorialorsai.com/category/epocas/')
html=response.read()

soup = BeautifulSoup(html,'html5lib')

#print(soup.prettify())

#print(soup.title)

#print(soup.title.name)

#print(soup.title.string)

#print(soup.p)

#print(soup.p.parent.name)

#print(soup.p['class'])

#soup.find_all('h2')

#soup.find_all('p')

#soup.find(id='nav_right')

cadena='victor'
print(type(cadena))

print('despues---')

for etiqueta in soup.find_all(['h2','p']):    
    print(type(etiqueta))
    print('---------')
    print(etiqueta.text)
    print('--------->>>')
    #print(etiqueta['h2'])
    #print(etiqueta.get('h2'))


            
        #file1 = open('aaaaaaaaaa.txt',"a+")  
    #print(type(str(p.text)))     
    #print(type(p.text))     
    #file1.write(unicode(p.string)+'vic')         
    #file1.write(str(bytes(p.text,encoding='utf8'))+cadena)         
    #print(p.text)
        #file1.write(p.string+cadena)         
    #file1.write(cadena)         
        #file1.close()
# Out:
# <class 'str'>
# despues---
# <class 'bs4.element.Tag'>
# Año 2004
# <class 'bs4.element.Tag'>
# El año prolífico. Orsai empezó a lo loco, con más de cien textos en su primer año. Eso sí: eran relatos más cortos y menos pensados (lo digo como virtud, no como defecto). Aquí están todos.
# <class 'bs4.element.Tag'>
# Año 2005
# <class 'bs4.element.Tag'>
# El año rebelde. En esta época nacieron casi todos los textos en los que despotrico contra España, porque me costaba adaptarme. También es el inicio de la saga del tataranieto Wuong.
# <class 'bs4.element.Tag'>
# Año 2006
# <class 'bs4.element.Tag'>
# El año tecnológico. Por alguna razón misteriosa, en esta época escribo muchos textos sobre avances en la tecnología. También dejo de fumar (por breves meses) y los relatos son más toscos.
# <class 'bs4.element.Tag'>
# Año 2007
# <class 'bs4.element.Tag'>
# El año introspectivo. En esta época del blog empiezo a escribir menos (cada quince días) y me centro en historias de infancia y adolescencia, que será el germen de "El pibe que arruinaba las fotos".
# <class 'bs4.element.Tag'>
# Año 2008
# <class 'bs4.element.Tag'>
# El año del primer libro. En esta época se publica "España decí alpiste" con una compilación de textos nostálgicos y prepotentes. Sigo escribiendo sobre infancia y adolescencia.
# <class 'bs4.element.Tag'>
# Año 2009
# <class 'bs4.element.Tag'>
# El año sabático. Muy pocos textos en esta época de Orsai, a causa de que Chiri se viene a vivir a España. Aparece el segundo libro con relatos del blog: "El pibe que arruinaba las fotos".
# <class 'bs4.element.Tag'>
# Año 2010
# <class 'bs4.element.Tag'>
# El año del volantazo. Paso muchos meses en silencio, pero a finales septiembre aparezco con textos nuevos. Empieza a gestarse la idea de hacer una revista de literatura llamada "Orsai".
# <class 'bs4.element.Tag'>
# Año 2011
# <class 'bs4.element.Tag'>
# El año de la revista. Los textos de Orsai vuelven a ser muchos en esta época, pero (para tristeza de los lectores) muy enfocados al proyecto de la revista. Pocos cuentos y relatos.
# <class 'bs4.element.Tag'>
# Año 2012
# <class 'bs4.element.Tag'>
# El año del fin del mundo. Según los mayas, este es el último año de la Humanidad. Chiri se vuelve a Argentina. Yo, por las dudas, rediseño todo el blog para que el caos nos encuentre presentables.
# <class 'bs4.element.Tag'>
# Año 2013
# <class 'bs4.element.Tag'>
# El último año de la revista. Año de cambios, libros y ediciones felices. El fin de Orsai como revista y el comienzo de Bonsai, su hermana menor. Pocos textos de literatura personal en el blog, pero es que estoy tomando carrera.
# <class 'bs4.element.Tag'>
# Año 2014
# <class 'bs4.element.Tag'>
# El año que Orsai pisa la década. Este blog nació el 27 de febrero de 2004, es decir que al principio de este 2014 hará diez años que escribo boludeces en directo. Posiblemente lo festeje con más boludeces.
# <class 'bs4.element.Tag'>
# Año 2015
# <class 'bs4.element.Tag'>
# El año de la senectud. Después de doce años de escribir en internet, me empecé a poner cascarrabias, predecible y lento de reflejos. Escribo poco, mal y desprolijo, mientras espero que llegue la sabiduría.
# <class 'bs4.element.Tag'>
