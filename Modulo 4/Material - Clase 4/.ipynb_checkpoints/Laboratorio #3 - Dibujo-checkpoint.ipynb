# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)

# %%
black_img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(black_img)

# %%
#cv2.rectangle(black_img,pt1=(384,0),pt2=(510,128),color=(0,255,0),thickness=5)
#plt.imshow(black_img)

#cv2.rectangle(imagen,pt1,pt2,color,grosor)
#plt.imshow(black_img)

cv2.rectangle(black_img, pt1=(384,0),pt2=(510,128),color=(0,255,0),thickness=5)
plt.imshow(black_img)

# %%
#cv2.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=5)
#plt.imshow(black_img)

cv2.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=5)
plt.imshow(black_img)

# %%
#cv2.circle(img=black_img,center=(100,100), radius=50, color=(255,0,0), thickness=5)
#plt.imshow(black_img)

#cv2.circle(imagen,centro,radio,color,grosor)
cv2.circle(img=black_img,center=(100,100),radius=50,color=(255,0,0),thickness=5)
plt.imshow(black_img)

# %%
#cv2.circle(img=black_img, center=(400,400), radius=50, color=(255,0,0), thickness=-1)
#plt.imshow(black_img)

cv2.circle(black_img,(400,400),50,(255,0,0),-1)
plt.imshow(black_img)

# %%
#cv2.line(black_img,pt1=(0,0), pt2=(511,511),color=(102,255,255), thickness=5)
#plt.imshow(black_img)

#cv2.line(imagen,punto_inicial, punto_final, color, grosor)
cv2.line(black_img,pt1=(0,0),pt2=(511,511),color=(102,255,255), thickness=5)
plt.imshow(black_img)

# %%
#font = cv2.FONT_HERSHEY_SIMPLEX
#cv2.putText(black_img, text="Hola", org=(10,500),fontFace=font,fontScale=4,color=(255,255,255),thickness=2,lineType=cv2.LINE_AA)
#plt.imshow(black_img)

#cv2.putText(imagen,texto,posicion,fuente,tamanoFuente,Color,Grosor,tipoLinea)
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(black_img,'Hola',(10,500),font,4,(255,255,255),2,cv2.LINE_AA)
plt.imshow(black_img)
